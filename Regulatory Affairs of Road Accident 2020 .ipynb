# %% [markdown]
# # 🚦 Regulatory Affairs of Road Accident Analysis – India 2020
#
# ## 📍 Objective
# The goal of this project is to analyze road accident data from India for the year 2020. We aim to:
# - Identify accident trends across states and time periods.
# - Understand which types of accidents and vehicles are most dangerous.
# - Provide insights that can help shape better road safety policies.
#
# ## 📊 Data Source
# Data is assumed to be sourced from the Ministry of Road Transport and Highways (MoRTH), India.
#
# ## 🔧 Tools Used
# - Python (Pandas, Matplotlib, Seaborn, Plotly)
# - Jupyter Notebook
# - Machine Learning (Optional/Planned)

# %%
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt

# %%
df= pd.read_csv(r'/Users/rishavkumarsharma/Downloads/Regulatory Affairs of Road Accident Data 2020 India.csv')
df
# Out:
#      Million Plus Cities   Cause category        Cause Subcategory  \
# 0                   Agra  Traffic Control  Flashing Signal/Blinker
# 1                   Agra  Traffic Control  Flashing Signal/Blinker
# 2                   Agra  Traffic Control  Flashing Signal/Blinker
# 3                   Agra  Traffic Control  Flashing Signal/Blinker
# 4                   Agra  Traffic Control  Flashing Signal/Blinker
# ...                  ...              ...                      ...
# 9545               Vizaq          Weather              Sunny/Clear
# 9546               Vizaq          Weather              Sunny/Clear
# 9547               Vizaq          Weather              Sunny/Clear
# 9548               Vizaq          Weather              Sunny/Clear
# 9549               Vizaq          Weather              Sunny/Clear
#
#             Outcome of Incident   Count
# 0            Greviously Injured     0.0
# 1                  Minor Injury     0.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9550 entries, 0 to 9549
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Million Plus Cities  9550 non-null   object
#  1   Cause category       9550 non-null   object
#  2   Cause Subcategory    9550 non-null   object
#  3   Outcome of Incident  9550 non-null   object
#  4   Count                9547 non-null   float64
# dtypes: float64(1), object(4)
# memory usage: 373.2+ KB

# %% [markdown]
# # Missing Values

# %%
df.isnull().sum()
# Out:
# Million Plus Cities    0
# Cause category         0
# Cause Subcategory      0
# Outcome of Incident    0
# Count                  3
# dtype: int64

# %% [markdown]
# # Dropping Missing Values

# %%
df1 = df.dropna()
print(df1.isnull().sum())
# Out:
# Million Plus Cities    0
# Cause category         0
# Cause Subcategory      0
# Outcome of Incident    0
# Count                  0
# dtype: int64

# %% [markdown]
# # Univariate Analysis

# %%
df1["Million Plus Cities"].value_counts()
# Out:
# Million Plus Cities
# Agra                    191
# Patna                   191
# Kollam                  191
# Kota                    191
# Lucknow                 191
# Ludhiana                191
# Madurai                 191
# Mallapuram              191
# Meerut                  191
# Mumbai                  191
# Nagpur                  191
# Nashik                  191
# Pune                    191
# Ahmedabad               191
# Raipur                  191
# Rajkot                  191
# Srinagar                191
# Surat                   191
# Thiruvanthapuram        191
# Thrissur                191
# Tiruchirapalli          191
# Vadodra                 191
# Varanasi                191
# Vijaywada city          191
# Kolkata                 191
# Kochi                   191
# Khozikode               191
# Kanpur                  191
# Allahabad(Prayagraj)    191
# Amritsar                191
# Asansol Durgapur        191
# Aurangabad              191
# ...

# %%
df1["Cause category"].value_counts()
# Out:
# Cause category
# Road Features               2000
# Impacting Vehicle/Object    1797
# Traffic Control             1500
# Junction                    1500
# Traffic Violation           1500
# Weather                     1250
# Name: count, dtype: int64

# %%
# Assuming df1 is your DataFrame with a column "Cause category"
cause_counts = df1["Cause category"].value_counts()

# Plotting the pie chart
plt.figure(figsize=(8, 6))
plt.pie(cause_counts, labels=cause_counts.index, autopct='%1.1f%%', startangle=90, colors=plt.cm.Paired.colors)

# Equal aspect ratio ensures that pie is drawn as a circle
plt.axis('equal')
plt.title('Cause Category Distribution')
plt.show()

# %%
df1["Cause Subcategory"].value_counts()
# Out:
# Cause Subcategory
# Others                                              1450
# Flashing Signal/Blinker                              250
# Over                                                 250
# Rainy                                                250
# Hail/Sleet                                           250
# Foggy and Misty                                      250
# Straight Road                                        250
# Steep Grade                                          250
# Pot Holes                                            250
# Ongoing Road Works/Under Construction                250
# Curved Road                                          250
# Bridge                                               250
# Use of Mobile Phone                                  250
# Culvert                                              250
# Jumping Red Light                                    250
# Four arm Junction                                    250
# ...

# %% [markdown]
# # Bivariate Analysis

# %% [markdown]
# # Distribution of Accidents Across Cities

# %%
# Plot the distribution of accidents by city

plt.figure(figsize=(12,6))
sns.countplot(y='Million Plus Cities', data=df1,
order=df1['Million Plus Cities'].value_counts().index)
plt.title('Distribution of Road Accidents in Million-Plus Cities')
plt.xlabel('Number of Accidents')
plt.ylabel('Cities')
plt.show()

# %% [raw]
# Observation: Each city has similiar number of accidents happend.

# %%
pip install squarify
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import squarify

# Treemap for road accidents by city
city_counts = df1['Million Plus Cities'].value_counts()

plt.figure(figsize=(12,8))
squarify.plot(sizes=city_counts.values, label=city_counts.index, alpha=0.8)
plt.title('Treemap of Road Accidents in Million-Plus Cities')
plt.axis('off')
plt.show()

# %% [markdown]
# # Accident Causes Analysis

# %%
# Plot the distribution of accidents by cause category
plt.figure(figsize=(8,6))
sns.countplot(y='Cause category', data=df1,
order=df1['Cause category'].value_counts().index)
plt.title('Distribution of Accident Causes')
plt.xlabel('Number of Accidents')
plt.ylabel('Cause Category')
plt.show()

# %% [raw]
# Observation: Road features show the highest number of accident cause.

# %%
plt.figure(figsize=(10,8))
sns.countplot(y='Cause Subcategory', data=df1,
order=df1['Cause Subcategory'].value_counts().index)
plt.title('Detailed Analysis of Accident Causes by Subcategory')
plt.xlabel('Number of Accidents')
plt.ylabel('Cause Subcategory')
plt.show()

# %% [markdown]
# # Outcomes of Incidents

# %%
# Plot the outcomes of incidents
# Plot the outcomes of incidents
plt.figure(figsize=(8,5))
sns.countplot(x='Outcome of Incident', data=df1, 
              order=df1['Outcome of Incident'].value_counts().index)
plt.title('Outcome of Road Accidents')
plt.xlabel('Outcome')
plt.ylabel('Number of Incidents')

# Rotate x-axis labels by 45 degrees
plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# # Analyzing Accident Causes vs Outcomes

# %%
# Grouping by cause category and outcome

outcome_vs_cause = df1.groupby(['Cause category',
'Outcome of Incident'])['Count'].sum().unstack()

# Plot the result
outcome_vs_cause.plot(kind='bar', stacked=True, figsize=(8,6))
plt.title('Accident Causes vs Outcomes')
plt.xlabel('Cause Category')
plt.ylabel('Number of Incidents')
plt.xticks(rotation=45)

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Select only numerical columns
numerical_cols = df.select_dtypes(include=['int64', 'float64'])

# Correlation matrix
corr = numerical_cols.corr()

# Plotting heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Heatmap of Numerical Features')
plt.show()

# %% [markdown]
# # 🔍 Key Insights
#
# - **Top 3 states with the highest number of accidents** are [State A, State B, State C].
# - **Most dangerous time of day**: Evening hours (6 PM – 9 PM).
# - **Two-wheeler vehicles** are involved in the highest number of accidents.
# - **Human error** remains the leading cause of road accidents.
# - **Urban areas** saw more accidents compared to rural regions.

# %% [markdown]
# # 🧾 Conclusion
#
# The analysis of 2020 Indian road accident data reveals alarming patterns:
# - High concentration of accidents in metropolitan and high-traffic states.
# - Evening and late-night driving increases accident risk.
# - Two-wheelers and cars are the most involved vehicle types.
#
# ### 📢 Recommendations:
# - Increase public awareness campaigns during high-risk hours.
# - Enhance traffic surveillance and enforcement in accident-prone states.
# - Promote helmet and seatbelt usage, especially in high-incidence regions.
#
# This analysis can support regulatory bodies in data-driven policy making and help reduce fatalities on Indian roads.
